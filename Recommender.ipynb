# %% [markdown]
# ## Data exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

## For multiple outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

## Load the data
file_path = "/home/miroslav/Downloads/BX-CSV-Dump/"
ratings = pd.read_csv(file_path + "BX-Book-Ratings.csv", sep =";", encoding = "ISO-8859-1")
books = pd.read_csv(file_path + "BX-Books.csv", sep =";", escapechar = "\\", encoding = "ISO-8859-1")
users = pd.read_csv(file_path + "BX-Users.csv", sep =";", encoding = "ISO-8859-1")

## By sampling from the dataset, we find nescaped HTML chars, NaN ages, implicit ratings
## User-ID is 1 based unlike default indexing
orig_ratings_l = ratings.shape[0]; 
orig_books_l = books.shape[0]; 
orig_users_l = users.shape[0];
orig_ratings_l; orig_books_l; orig_users_l
ratings.sample(5); books.sample(5); users.sample(5)
# Out:
# 1149780
# 271379
# 278858
#          User-ID        ISBN  Book-Rating
# 343160     81771  0156027321           10
# 873044    211426  0312151993            0
# 1037568   248122  0395974682           10
# 421081    100648  0142000329            0
# 1030602   246507  0385729340            0
#               ISBN                                  Book-Title  \
# 34711   0140263454                          The Raven: A Novel
# 229416  080520928X                        World of Our Fathers
# 249886  0713723572  Lizards of the World (Of the World Series)
# 17185   0684856220                    CUPID AND DIANA: A Novel
# 252724  0140171460                          Prized Possessions
#
#                  Book-Author  Year-Of-Publication         Publisher  \
# 34711        Peter Landesman                 1997     Penguin Books
# 229416           Irving Howe                 1990  Random House Inc
# 249886        Chris Mattison                 1998         Blandford
# 17185   Christina Bartolomeo                 1999          Scribner
# 252724           L.R. Wright                 1994       Penguin USA
#
#                                               Image-URL-S  \
# 34711   http://images.amazon.com/images/P/0140263454.0...
# 229416  http://images.amazon.com/images/P/080520928X.0...
# 249886  http://images.amazon.com/images/P/0713723572.0...
# 17185   http://images.amazon.com/images/P/0684856220.0...
# 252724  http://images.amazon.com/images/P/0140171460.0...
#
#                                               Image-URL-M  \
# 34711   http://images.amazon.com/images/P/0140263454.0...
# 229416  http://images.amazon.com/images/P/080520928X.0...
# 249886  http://images.amazon.com/images/P/0713723572.0...
# 17185   http://images.amazon.com/images/P/0684856220.0...
# 252724  http://images.amazon.com/images/P/0140171460.0...
#
#                                               Image-URL-L
# 34711   http://images.amazon.com/images/P/0140263454.0...
# 229416  http://images.amazon.com/images/P/080520928X.0...
# 249886  http://images.amazon.com/images/P/0713723572.0...
# 17185   http://images.amazon.com/images/P/0684856220.0...
# 252724  http://images.amazon.com/images/P/0140171460.0...
#         User-ID                          Location   Age
# 159556   159557  grimsby, england, united kingdom  24.0
# 106220   106221         sandiego, california, usa   NaN
# 111103   111104   colorado springs, colorado, usa   NaN
# 64540     64541           milan, lombardia, italy  33.0
# 245357   245358     iloilo city, n/a, philippines  28.0

# %%
## Occurance percentages of nan ages and implicit ratings
users['Age'].isnull().sum()/users.shape[0]
ratings[ratings['Book-Rating'] == 0].shape[0]/ratings.shape[0]
explicit_ratings = ratings[ratings['Book-Rating'] != 0]
implicit_ratings = ratings[ratings['Book-Rating'] == 0]
# Out:
# 0.4100946971495873
# 0.6228226269373272

# %%
## Check for outliers
books[books['Year-Of-Publication'] > 2004]
users[users['Age'] > 110]
# Out:
#               ISBN                                         Book-Title  \
# 3541    0140124373                                          Red Dwarf
# 12783   0380816792                                   A Rose in Winter
# 26167   006272004X                          The Astrologer's Handbook
# 30011   068160204X                                         The Royals
# 37488   0671746103  MY TEACHER FRIED MY BRAINS (RACK SIZE) (MY T
# 76864     76865          arrasate, gipuzkoa, euskal herria  209.0
# ...         ...                                        ...    ...
# 192412   192413                   elverta, california, usa  228.0
# 196035   196036             san francisco, california, usa  148.0
# 210012   210013         sydney, new south wales, australia  204.0
# 211520   211521      santa maria da feira, porto, portugal  223.0
# 212515   212516                   lisboa, lisboa, portugal  113.0
# 216665   216666      christchurch, canterbury, new zealand  208.0
# 217550   217551                barcelona, catalunya, spain  124.0
# 218682   218683                     ceres, california, usa  157.0
# 221391   221392                      tallinn, n/a, estonia  123.0
# 222659   222660                      opelika, alabama, usa  114.0
# 224633   224634           fuerteventura, las palmas, spain  111.0
# 224763   224764                  rockaway, new jersey, usa  116.0
# 225172   225173                       haifa, haifa, israel  115.0
# 225525   225526                       kamuela, hawaii, usa  124.0
# 225959   225960               babenhausen, hessen, germany  146.0
# 226615   226616                       tucson, arizona, usa  204.0
# 227814   227815                   nowhere, new jersey, usa  118.0
# 231945   231946                 san diego, california, usa  116.0
# 242213   242214                      golden, colorado, usa  228.0
# 245084   245085                      succ, new jersey, usa  123.0
# 245230   245231               christchurch, canterbury, nz  220.0
# 250633   250634                  singapore, n/a, singapore  114.0
# 257113   257114                glen ridge, new jersey, usa  210.0
# 257429   257430    reutlingen, baden-wuerttemberg, germany  200.0
# 261553   261554                      arak, tennessee, iran  143.0
# 263066   263067      villa gesell, buenos aires, argentina  113.0
# 264933   264934                      madrid, madrid, spain  140.0
# 266534   266535                     lizvill, arkansas, usa  116.0
# 275582   275583          koblenz, rheinland-pfalz, germany  189.0
# 276047   276048                        wien, wien, austria  127.0
#
# [96 rows x 3 columns]

# %%
## Check for duplicated data
len(users[users.duplicated(['User-ID'])].groupby('User-ID'))
len(books[books.duplicated(['ISBN'])].groupby('ISBN').size())

## Check for name duplicates
books[books.duplicated(['Book-Title', 'Book-Author'], keep=False)].groupby('Book-Title').size().sort_values()

## Check for the number of variations of Lord of The Rings
len(books[books['Book-Title'].str.contains('Lord of The Rings', case=False)])
# Out:
# 0
# 0
# Book-Title
# !%@ (A Nutshell handbook)                                           2
# Ship of Magic (The Liveship Traders, Book 1)                        2
# Ship of the Line (Star Trek: The Next Generation)                   2
# Shipwrecks                                                          2
# Shirley Temple: American Princess                                   2
# Shiva Dancing                                                       2
# Shivers                                                             2
# Shoah                                                               2
# Shock                                                               2
# Shock Wave (Dirk Pitt Adventures (Paperback))                       2
# Shogun                                                              2
# Ship of Gold in the Deep Blue Sea                                   2
# Shoot the Moon                                                      2
# Shooting Elvis                                                      2
# Shopping                                                            2
# Short English handbook                                              2
# Shot in the Heart                                                   2
# Shot on Location                                                    2
# Show Me a Hero                                                      2
# Shrine                                                              2
# Shrink Rap                                                          2
# Shroud for a Nightingale                                            2
# Shudder Again: 22 Tales of Sex and Horror                           2
# Shooting Chant : A Ella Clah Novel (Ella Clah)                      2
# Ship of Fools                                                       2
# Shinju                                                              2
# Shining Hero                                                        2
# Shattered Mirror                                                    2
# Shattered Silk                                                      2
# Shattering Glass                                                    2
#                                                                    ..
# Beloved                                                            10
# Lolita                                                             10
# Illusions                                                          10
# Heidi                                                              10
# Hannibal                                                           10
# The Hobbit                                                         10
# Madame Bovary                                                      10
# Dolores Claiborne                                                  10
# Anna Karenina                                                      10
# The Wind in the Willows                                            11
# Carrie                                                             11
# Robinson Crusoe                                                    11
# Matilda                                                            11
# Sense and Sensibility                                              12
# The Wedding                                                        12
# Phonics Fun: Reading Program, Pack 4 (Clifford the Big Red Dog)    12
# Emma                                                               13
# The Night Before Christmas                                         13
# Nemesis                                                            13
# Fahrenheit 451                                                     13
# Black Beauty                                                       14
# Frankenstein                                                       14
# Great Expectations                                                 16
# Dracula                                                            16
# Jane Eyre                                                          18
# Pride and Prejudice                                                18
# The Secret Garden                                                  19
# Adventures of Huckleberry Finn                                     20
# Wuthering Heights                                                  20
# Little Women                                                       21
# dtype: int64
# 119

# %%
## Check for users with no ratings for removal, 
len(users[~users["User-ID"].isin(ratings["User-ID"])])/len(users)

## Remove useless rows and display new dimensions - ratings have no useless rows
books = books.dropna(axis=0, subset=['ISBN', 'Book-Title', 'Book-Author'])
ratings = ratings.dropna(axis=0, subset=['User-ID', 'Book-Rating'])
users = users.dropna(axis=0, subset=['User-ID'])
users = users[users["User-ID"].isin(ratings["User-ID"])]
books = books[books['ISBN'].isin(ratings['ISBN'])]
ratings.shape[0]/orig_ratings_l; books.shape[0]/orig_books_l; users.shape[0]/orig_users_l;

## Find average number of ratings and average rating per user and overall, rating range
average_ratings = explicit_ratings.groupby("User-ID")["Book-Rating"].agg(['count', 'mean'])
average_ratings
average_ratings.describe()

## Make sure no user rated a movie twice
len(explicit_ratings[explicit_ratings.duplicated(["User-ID", "ISBN"])])

## Check if implicit feedback is repeated or not
len(implicit_ratings[implicit_ratings.duplicated(["User-ID", "ISBN"])])

## Number of different titles
book_rating_view = explicit_ratings.merge(books, how='left', on='ISBN')
book_rating_view_grouped = book_rating_view.groupby(['Book-Title', 'Book-Author']).agg(['mean'])
len(book_rating_view_grouped)
# book_rating_view_grouped.sort_values(by=('Book-Rating', 'mean'), ascending=False)['Book-Rating'].head(10) # This is not the best way, better bayesian average
# Out:
# 0.0
# 1.0
# 0.9955449758455887
# 0.37755058129944274
#          count       mean
# User-ID
# 8            7   5.571429
# 9            1   6.000000
# 10           1   6.000000
# 12           1  10.000000
# 14           3   5.333333
# 16           1   9.000000
# 17           4   5.250000
# 19           1   7.000000
# 22           1   7.000000
# 26           2   9.500000
# 32           1   8.000000
# 39           2   7.500000
# 42           1   7.000000
# 44           1   8.000000
# 51           1   9.000000
# 53           4   7.000000
# 56           2   8.000000
# 64           1   7.000000
# 67           1   7.000000
# 69           3   5.666667
# 70           1  10.000000
# 73           1   5.000000
# 75           1   5.000000
# 78           1   8.000000
# 81           1   5.000000
# 82           1  10.000000
# 83           1   7.000000
# 85           1   5.000000
# 86           1   4.000000
# 87           2   8.000000
# ...        ...        ...
# 278759       1   1.000000
# 278760       1   7.000000
# 278764       1   2.000000
# 278767       1   6.000000
# 278772       1  10.000000
# 278773       4   6.750000
# 278777       1   5.000000
# 278778       1   8.000000
# 278782       3   6.333333
# 278786       1   6.000000
# 278798       2   7.000000
# 278800       1   9.000000
# 278806       1   9.000000
# 278807       1  10.000000
# 278818       2   9.500000
# 278820       1   3.000000
# 278823       1   7.000000
# 278824       1   6.000000
# 278825       1   5.000000
# 278828       1   8.000000
# 278831       1  10.000000
# 278832       3  10.000000
# 278836       1   8.000000
# 278843      20   7.700000
# 278844       3   6.333333
# 278846       1   8.000000
# 278849       1   9.000000
# 278851      14   6.500000
# 278852       1   8.000000
# 278854       6   7.000000
#
# [77805 rows x 2 columns]
#               count          mean
# count  77805.000000  77805.000000
# mean       5.573819      7.459926
# std       44.001879      1.630394
# min        1.000000      1.000000
# 25%        1.000000      6.600000
# 50%        1.000000      7.727273
# 75%        3.000000      8.500000
# max     8524.000000     10.000000
# 0
# 0
# 139648

# %%
## Clear memory
del book_rating_view, implicit_ratings, explicit_ratings, average_ratings
del books, users

# %% [markdown]
# ## Data preparation

# %%
## Attempt 1 - 105000×135000×4 = 56 GB :(
utility = ratings.pivot(index='ISBN', columns='User-ID', values='Book-Rating')

## Attempt 2
ratings['ISBN'].replace(ratings['ISBN'], pd.Series([book_rating_view.get_group(key).min() for key,_ in book_rating_view]))

## Attempt 3 - even sparse data structure doesn't work
isbn_vector = books.groupby(['Book-Title']).first()
utility = pd.DataFrame(np.nan, index=explicit_ratings['User-ID'], columns=users['User-ID']).sparse()
for name, group in explicit_ratings.groupby('User-ID'):
    user_vector = pd.DataFrame(np.nan, index=isbn_vector, columns = [name])
    for row, index in group:
        user_vector[books.groupby(['Book-Title']).get_group(row['ISBN']).first()] = row['Book-Rating']
    utility.join(user_vector)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-53-dc3d0eef197f> in <module>()
#       7 ## Attempt 3 - even sparse data structure doesn't work
#       8 isbn_vector = books.groupby(['Book-Title']).first()
# ----> 9 utility = pd.DataFrame(np.nan, index=explicit_ratings['User-ID'], columns=users['User-ID']).sparse()
#      10 for name, group in explicit_ratings.groupby('User-ID'):
#      11     user_vector = pd.DataFrame(np.nan, index=isbn_vector, columns = [name])
#
# /home/miroslav/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     338                     dtype, data = _infer_dtype_from_scalar(data)
#     339
# --> 340                 values = np.empty((len(index), len(columns)), dtype=dtype)
#     341                 values.fill(data)
#     342                 mgr = self._init_ndarray(values, index, columns, dtype=dtype,
#
# MemoryError:

# %%
## Load the data
file_path = "/home/miroslav/Downloads/BX-CSV-Dump/"
ratings = pd.read_csv(file_path + "BX-Book-Ratings.csv", sep =";", encoding = "ISO-8859-1")
books = pd.read_csv(file_path + "BX-Books.csv", sep =";", escapechar = "\\", encoding = "ISO-8859-1")
users = pd.read_csv(file_path + "BX-Users.csv", sep =";", encoding = "ISO-8859-1")

## Remove useless rows
books = books.dropna(axis=0, subset=['ISBN', 'Book-Title', 'Book-Author'])
# ratings = ratings.dropna(axis=0, subset=['User-ID', 'Book-Rating'])
users = users.dropna(axis=0, subset=['User-ID'])
users = users[users["User-ID"].isin(ratings["User-ID"])]

## Remove books which don't have explicit ratings - try to replace with user average later
explicit_ratings = ratings[ratings['Book-Rating'] != 0]
books = books[books['ISBN'].isin(explicit_ratings['ISBN'])]

# %%
## Normalize explicit ratings by subtracting the mean
normalized_ratings = explicit_ratings.groupby('User-ID').transform(lambda df: df-df.mean())
explicit_ratings = explicit_ratings.drop('Book-Rating', axis=1)
explicit_ratings = explicit_ratings.join(normalized_ratings)
explicit_ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 1         276726   0155061224     0.000000
# 3         276729   052165615X    -1.500000
# 4         276729   0521795028     1.500000
# 6         276736   3257224281     0.000000
# 7         276737   0600570967     0.000000
# 8         276744   038550120X     0.000000
# 9         276745    342310538     0.000000
# 16        276747   0060517794     1.000000
# 19        276747   0671537458     1.000000
# 20        276747   0679776818     0.000000
# 21        276747   0943066433    -1.000000
# 23        276747   1885408226    -1.000000
# 24        276748   0747558167     0.000000
# 27        276751   3596218098     0.000000
# 28        276754   0684867621     0.000000
# 29        276755   0451166892     0.000000
# 30        276760   8440682697     0.000000
# 33        276762   0380711524     0.000000
# 44        276762   3453092007     3.000000
# 49        276762   3453213025    -2.000000
# 55        276762  N3453124715    -1.000000
# 57        276768   9057868059     0.000000
# 59        276772   0553572369    -2.000000
# 61        276772   3499230933     1.000000
# 62        276772   3596151465     1.000000
# 66        276774   3442136644     0.000000
# 69        276780   8484330478     0.000000
# 70        276780   8484332039     0.000000
# 71        276786   2864322102    -0.500000
# 77        276786   8437606322     1.500000
# ...          ...          ...          ...
# 1149690   276688   0425156737    -5.724138
# 1149697   276688   044661193X    -0.724138
# 1149703   276688   0553074938     0.275862
# 1149704   276688   0553074946     1.275862
# 1149705   276688   0553088467     0.275862
# 1149709   276688   0553089234     2.275862
# 1149711   276688   0553566040    -1.724138
# 1149713   276688   0553572512    -0.724138
# 1149714   276688   0553575090    -0.724138
# 1149715   276688   0553575104    -1.724138
# 1149717   276688   0671015591    -5.724138
# 1149719   276688   0671563149    -1.724138
# 1149728   276688   0684195569     2.275862
# 1149729   276688   0684804484     2.275862
# 1149738   276688   0688156134     0.275862
# 1149739   276688   0743202694     2.275862
# 1149741   276688   0786011157    -0.724138
# 1149743   276688   0836218655     2.275862
# 1149744   276688   0836236688     2.275862
# 1149745   276688   0892966548     2.275862
# 1149746   276688   1551669315    -1.724138
# 1149747   276688   1575660792    -0.724138
# 1149761   276704   0345386108    -0.400000
# 1149762   276704   0380796155    -1.400000
# 1149771   276704   0743211383     0.600000
# 1149773   276704   0806917695    -1.400000
# 1149775   276704   1563526298     2.600000
# 1149777   276709   0515107662     0.000000
# 1149778   276721   0590442449     0.000000
# 1149779   276723  05162443314     0.000000
#
# [433671 rows x 3 columns]

# %%
## Reduce dimensionality of ISBN vector
books_grouped = books.groupby(['Book-Title', 'Book-Author'])
for index, row in explicit_ratings.iterrows():
    book_title = books[books['ISBN'] == row['ISBN']]['Book-Title'].min()
    book_author = books[books['ISBN'] == row['ISBN']]['Book-Author'].min()
    #if (~pd.isnull(book_title) and ~pd.isnull(book_author)):
    if type(book_title) == str and type(book_author) == str:
        explicit_ratings.set_value(index, 'ISBN', books_grouped.get_group((book_title, book_author))['ISBN'].min());
explicit_ratings

# %%
## Send explicit ratings to the database
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:root@localhost/books')

# books.to_sql('books', engine)
# users.to_sql('users', engine)
explicit_ratings.to_sql('explicit_ratings', engine)
